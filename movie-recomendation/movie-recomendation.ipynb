# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from skimage import io
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = pd.read_csv('../datasets/movies.csv')
df.head(n=2)
# Out:
#        id     imdb_id                    title  \
# 0  414906   tt1877830               The Batman
# 1  634649  tt10872600  Spider-Man: No Way Home
#
#                              genres original_language  \
# 0            Crime-Mystery-Thriller                en
# 1  Action-Adventure-Science Fiction                en
#
#                                             overview  popularity  \
# 0  In his second year of fighting crime Batman un...    8195.597
# 1  Peter Parker is unmasked and no longer able to...    4716.995
#
#                                 production_companies release_date     budget  \
# 0  6th & Idaho-Dylan Clark Productions-DC Films-W...   2022-03-01  185000000
# 1   Marvel Studios-Pascal Pictures-Columbia Pictures   2021-12-15  200000000
#
#    ...  runtime    status                    tagline vote_average  vote_count  \
# 0  ...    176.0  Released          Unmask the truth.          7.8        4165
# 1  ...    148.0  Released  The Multiverse unleashed.          8.1       12300
#
#                                              credits  \
# 0  Robert Pattinson-Zoë Kravitz-Paul Dano-Jeffrey...
# 1  Tom Holland-Zendaya-Benedict Cumberbatch-Jacob...
#
#                                             keywords  \
# 0  crime fighter-secret identity-nightclub-politi...
# 1  new york city-loss of loved one-showdown-secre...
#
#                         poster_path                     backdrop_path  \
# 0  /74xTEgt7R36Fpooo50r9T25onhq.jpg  /tRS6jvPM9qPrrnx2KRp3ew96Yot.jpg
# 1  /1g0dhYtq4irTY1GPXvft6k4YLjm.jpg  /iQFcwSGbZXMkeyKrxbPnwnRo5fl.jpg
#
#                                      recommendations
# 0  335787-508947-696806-777270-833425-718032-5050...
# 1  646380-624860-568124-524434-580489-425909-4766...
#
# [2 rows x 21 columns]

# %% [markdown]
# <h2>Feature Extraction</h2>

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
from nltk.corpus import wordnet, stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
df['overview']= df['overview'].fillna('')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     /Users/klebervasconcelos/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/klebervasconcelos/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/klebervasconcelos/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
sample_df = df.sample(n=5)
sample_df.head()
# Out:
#             id    imdb_id                      title                genres  \
# 277193  278826  tt0092998         Eye on the Sparrow        Drama-TV Movie
# 62213   251689  tt1706481         Sex Express Coffee  Crime-Drama-Thriller
# 35277   169025  tt2638096  The Real Life of Teachers                Comedy
# 156305  313778        NaN  TNA Hardcore Justice 2010          Drama-Action
# 269544  270283  tt1485686               Boronia Boys                   NaN
#
#        original_language                                           overview  \
# 277193                en  True story of a blind couple who fought the au...
# 62213                 es  Police detective Escobar attempts to capture a...
# 35277                 fr  A comedy about a band of voyeuristic students ...
# 156305                en  Total Nonstop Action (TNA) Wrestling President...
# 269544                en  Kane and Darren are two 'rag and bone men' who...
#
#         popularity        production_companies release_date  budget  ...  \
# 277193       1.754                         NaN   1987-12-07       0  ...
# 62213        2.465                 MCM Studios   2010-05-25       0  ...
# 35277        4.816   Universal Pictures France   2013-02-20       0  ...
# 156305       1.960  Total Nonstop Action (TNA)   2010-08-08       0  ...
# 269544       0.915       Star Baby Productions   2009-08-25       0  ...
#
#         runtime    status                              tagline vote_average  \
# 277193     96.0  Released                                  NaN          7.0
# 62213      87.0  Released  Here, the holiest temptation falls.          4.2
# 35277      97.0  Released                                  NaN          4.8
# 156305    360.0  Released                                  NaN          5.0
# 269544     90.0  Released                                  NaN          2.0
#
#         vote_count                                            credits  \
# 277193           1  Mare Winningham-Keith Carradine-Sandy McPeak-K...
# 62213            9  Ricardo Bonno-Fernando Consagra-Diego de Erice...
# 35277          146  Lucien Jean-Baptiste-Audrey Fleurot-Emir Seghi...
# 156305           1  Rob Van Dam-Sabu-Scott Levy-Tommy Dreamer-Mark...
# 269544           1  Cameron Nugent-Tim Burns-Elspeth Ballantyne-Ma...
#
#                                   keywords                       poster_path  \
# 277193                                 NaN  /drMT2OnphALjOngvnQmhpObtRP1.jpg
# 62213   police investigation-online hookup  /uyKD8lPJcndgxY8ORSNplKapCM0.jpg
# 35277                                  NaN  /2j81UTWwKCISexGjxpWEaiX2fCg.jpg
# 156305             wrestling-pro wrestling  /wnjkyTwaSiONNqvmwHS8Xs0wlJY.jpg
# 269544                                 NaN  /lrh8QOH9Se0Rv59DTrS7XUXKZJ5.jpg
#
#                            backdrop_path  \
# 277193                               NaN
# 62213   /mHAXyacdn2do4RGF0BQ2392Js9Y.jpg
# 35277   /cCZ2a3HSAsmUPD2CjCcHKzyXAUK.jpg
# 156305                               NaN
# 269544                               NaN
#
#                                           recommendations
# 277193                                                NaN
# 62213                                                 NaN
# 35277   182219-325844-418333-66129-344268-262551-28373...
# 156305                                                NaN
# 269544                                                NaN
#
# [5 rows x 21 columns]

# %%
sample_df['overview']=sample_df['overview'].str.lower().apply(word_tokenize).apply(nltk.tag.pos_tag) # Applying part of speech tags.
sample_df.head()
# Out:
#             id    imdb_id                      title                genres  \
# 277193  278826  tt0092998         Eye on the Sparrow        Drama-TV Movie
# 62213   251689  tt1706481         Sex Express Coffee  Crime-Drama-Thriller
# 35277   169025  tt2638096  The Real Life of Teachers                Comedy
# 156305  313778        NaN  TNA Hardcore Justice 2010          Drama-Action
# 269544  270283  tt1485686               Boronia Boys                   NaN
#
#        original_language                                           overview  \
# 277193                en  [(true, JJ), (story, NN), (of, IN), (a, DT), (...
# 62213                 es  [(police, NNS), (detective, JJ), (escobar, NN)...
# 35277                 fr  [(a, DT), (comedy, NN), (about, IN), (a, DT), ...
# 156305                en  [(total, JJ), (nonstop, JJ), (action, NN), ((,...
# 269544                en  [(kane, NN), (and, CC), (darren, NNS), (are, V...
#
#         popularity        production_companies release_date  budget  ...  \
# 277193       1.754                         NaN   1987-12-07       0  ...
# 62213        2.465                 MCM Studios   2010-05-25       0  ...
# 35277        4.816   Universal Pictures France   2013-02-20       0  ...
# 156305       1.960  Total Nonstop Action (TNA)   2010-08-08       0  ...
# 269544       0.915       Star Baby Productions   2009-08-25       0  ...
#
#         runtime    status                              tagline vote_average  \
# 277193     96.0  Released                                  NaN          7.0
# 62213      87.0  Released  Here, the holiest temptation falls.          4.2
# 35277      97.0  Released                                  NaN          4.8
# 156305    360.0  Released                                  NaN          5.0
# 269544     90.0  Released                                  NaN          2.0
#
#         vote_count                                            credits  \
# 277193           1  Mare Winningham-Keith Carradine-Sandy McPeak-K...
# 62213            9  Ricardo Bonno-Fernando Consagra-Diego de Erice...
# 35277          146  Lucien Jean-Baptiste-Audrey Fleurot-Emir Seghi...
# 156305           1  Rob Van Dam-Sabu-Scott Levy-Tommy Dreamer-Mark...
# 269544           1  Cameron Nugent-Tim Burns-Elspeth Ballantyne-Ma...
#
#                                   keywords                       poster_path  \
# 277193                                 NaN  /drMT2OnphALjOngvnQmhpObtRP1.jpg
# 62213   police investigation-online hookup  /uyKD8lPJcndgxY8ORSNplKapCM0.jpg
# 35277                                  NaN  /2j81UTWwKCISexGjxpWEaiX2fCg.jpg
# 156305             wrestling-pro wrestling  /wnjkyTwaSiONNqvmwHS8Xs0wlJY.jpg
# 269544                                 NaN  /lrh8QOH9Se0Rv59DTrS7XUXKZJ5.jpg
#
#                            backdrop_path  \
# 277193                               NaN
# 62213   /mHAXyacdn2do4RGF0BQ2392Js9Y.jpg
# 35277   /cCZ2a3HSAsmUPD2CjCcHKzyXAUK.jpg
# 156305                               NaN
# 269544                               NaN
#
#                                           recommendations
# 277193                                                NaN
# 62213                                                 NaN
# 35277   182219-325844-418333-66129-344268-262551-28373...
# 156305                                                NaN
# 269544                                                NaN
#
# [5 rows x 21 columns]

# %%
sample_df['overview'].head()
# Out:
# 277193    [(true, JJ), (story, NN), (of, IN), (a, DT), (...
# 62213     [(police, NNS), (detective, JJ), (escobar, NN)...
# 35277     [(a, DT), (comedy, NN), (about, IN), (a, DT), ...
# 156305    [(total, JJ), (nonstop, JJ), (action, NN), ((,...
# 269544    [(kane, NN), (and, CC), (darren, NNS), (are, V...
# Name: overview, dtype: object

# %%
def get_wordnet_pos(tag):
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return wordnet.NOUN
    
sample_df['overview']= sample_df['overview'].apply(lambda x: [(word, get_wordnet_pos(pos_tag)) for (word, pos_tag) in x])
sample_df['overview'].head()
# Out:
# 277193    [(true, a), (story, n), (of, n), (a, n), (blin...
# 62213     [(police, n), (detective, a), (escobar, n), (a...
# 35277     [(a, n), (comedy, n), (about, n), (a, n), (ban...
# 156305    [(total, a), (nonstop, a), (action, n), ((, n)...
# 269544    [(kane, n), (and, n), (darren, n), (are, v), (...
# Name: overview, dtype: object

# %%
# Applying word lemmatizer.

wnl = WordNetLemmatizer()

sample_df['overview']= sample_df['overview'].apply(lambda x: [wnl.lemmatize(word, tag) for word, tag in x])

sample_df['overview']= sample_df['overview'].apply(lambda x: ' '.join(x))

sample_df.head()
# Out:
#             id    imdb_id                      title                genres  \
# 277193  278826  tt0092998         Eye on the Sparrow        Drama-TV Movie
# 62213   251689  tt1706481         Sex Express Coffee  Crime-Drama-Thriller
# 35277   169025  tt2638096  The Real Life of Teachers                Comedy
# 156305  313778        NaN  TNA Hardcore Justice 2010          Drama-Action
# 269544  270283  tt1485686               Boronia Boys                   NaN
#
#        original_language                                           overview  \
# 277193                en  true story of a blind couple who fight the aut...
# 62213                 es  police detective escobar attempt to capture an...
# 35277                 fr  a comedy about a band of voyeuristic student w...
# 156305                en  total nonstop action ( tna ) wrestle president...
# 269544                en  kane and darren be two 'rag and bone men ' who...
#
#         popularity        production_companies release_date  budget  ...  \
# 277193       1.754                         NaN   1987-12-07       0  ...
# 62213        2.465                 MCM Studios   2010-05-25       0  ...
# 35277        4.816   Universal Pictures France   2013-02-20       0  ...
# 156305       1.960  Total Nonstop Action (TNA)   2010-08-08       0  ...
# 269544       0.915       Star Baby Productions   2009-08-25       0  ...
#
#         runtime    status                              tagline vote_average  \
# 277193     96.0  Released                                  NaN          7.0
# 62213      87.0  Released  Here, the holiest temptation falls.          4.2
# 35277      97.0  Released                                  NaN          4.8
# 156305    360.0  Released                                  NaN          5.0
# 269544     90.0  Released                                  NaN          2.0
#
#         vote_count                                            credits  \
# 277193           1  Mare Winningham-Keith Carradine-Sandy McPeak-K...
# 62213            9  Ricardo Bonno-Fernando Consagra-Diego de Erice...
# 35277          146  Lucien Jean-Baptiste-Audrey Fleurot-Emir Seghi...
# 156305           1  Rob Van Dam-Sabu-Scott Levy-Tommy Dreamer-Mark...
# 269544           1  Cameron Nugent-Tim Burns-Elspeth Ballantyne-Ma...
#
#                                   keywords                       poster_path  \
# 277193                                 NaN  /drMT2OnphALjOngvnQmhpObtRP1.jpg
# 62213   police investigation-online hookup  /uyKD8lPJcndgxY8ORSNplKapCM0.jpg
# 35277                                  NaN  /2j81UTWwKCISexGjxpWEaiX2fCg.jpg
# 156305             wrestling-pro wrestling  /wnjkyTwaSiONNqvmwHS8Xs0wlJY.jpg
# 269544                                 NaN  /lrh8QOH9Se0Rv59DTrS7XUXKZJ5.jpg
#
#                            backdrop_path  \
# 277193                               NaN
# 62213   /mHAXyacdn2do4RGF0BQ2392Js9Y.jpg
# 35277   /cCZ2a3HSAsmUPD2CjCcHKzyXAUK.jpg
# 156305                               NaN
# 269544                               NaN
#
#                                           recommendations
# 277193                                                NaN
# 62213                                                 NaN
# 35277   182219-325844-418333-66129-344268-262551-28373...
# 156305                                                NaN
# 269544                                                NaN
#
# [5 rows x 21 columns]

# %%
def lammatization():
    import nltk
    nltk.download('punkt')
    nltk.download('averaged_perceptron_tagger')
    nltk.download('wordnet')
    from nltk.corpus import wordnet, stopwords
    from nltk.stem import WordNetLemmatizer
    from nltk.tokenize import word_tokenize
    df['overview']= df['overview'].fillna('')

    # Tokenizing the tweet base texts (splitting the text into individual words)
    # and applying part of speech tags to each word

    df['overview']=df['overview'].str.lower().apply(word_tokenize).apply(nltk.tag.pos_tag) 


    # Converting part of speeches to wordnet format.

    def get_wordnet_pos(tag):
        if tag.startswith('J'):
            return wordnet.ADJ
        elif tag.startswith('V'):
            return wordnet.VERB
        elif tag.startswith('N'):
            return wordnet.NOUN
        elif tag.startswith('R'):
            return wordnet.ADV
        else:
            return wordnet.NOUN


    df['overview']= df['overview'].apply(lambda x: [(word, get_wordnet_pos(pos_tag)) for (word, pos_tag) in x])

    # Applying word lemmatizer.

    wnl = WordNetLemmatizer()

    df['overview']= df['overview'].apply(lambda x: [wnl.lemmatize(word, tag) for word, tag in x])


    df['overview']= df['overview'].apply(lambda x: ' '.join(x))

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

df.drop_duplicates(inplace=True, ignore_index=True)
#df = df.groupby('title').first().reset_index()
df.fillna(value={i: ' ' for i in ['overview', 'genres', 'keywords', 'credits']}, inplace=True)

# lambda func for str split join
strOp= lambda x: ' '.join(x.split('-'))

df.overview = df.overview + df.keywords.apply(strOp) + df.genres.apply(strOp) + df.credits.apply(lambda x: ' '.join(x.replace(' ', '').split('-')[:3]))

#Define a TF-IDF Vectorizer Object. Remove all english stop words such as 'the', 'a'
tfidf = TfidfVectorizer(stop_words='english')

#Construct the required TF-IDF matrix by fitting and transforming the data
tfidf_matrix = tfidf.fit_transform(df['overview'])

display(pd.DataFrame(
    tfidf_matrix[:10, 7000:7070].toarray(),
    columns= tfidf.get_feature_names_out()[7000:7070],
    index = df.title[:10]).round())

print(tfidf_matrix.shape)
# Out:
#                              actionmattfarley  actionmatthewchamp  \
# title
# The Batman                                0.0                 0.0
# Spider-Man: No Way Home                   0.0                 0.0
# The Outfit                                0.0                 0.0
# Turning Red                               0.0                 0.0
# Sonic the Hedgehog 2                      0.0                 0.0
# Yaksha: Ruthless Operations               0.0                 0.0
# Moonfall                                  0.0                 0.0
# Uncharted                                 0.0                 0.0
# All the Old Knives                        0.0                 0.0
# Blacklight                                0.0                 0.0
#
#                              actionmatthewmercer  actionmatthewmodine  \
# title
# The Batman                                   0.0                  0.0
# Spider-Man: No Way Home                      0.0                  0.0
# The Outfit                                   0.0                  0.0
# Turning Red                                  0.0                  0.0
# Sonic the Hedgehog 2                         0.0                  0.0
# Yaksha: Ruthless Operations                  0.0                  0.0
# Moonfall                                     0.0                  0.0
# Uncharted                                    0.0                  0.0
# All the Old Knives                           0.0                  0.0
# Blacklight                                   0.0                  0.0
#
#                              actionmatthewreese  actionmatthewwillig  \
# title
# The Batman                                  0.0                  0.0
# Spider-Man: No Way Home                     0.0                  0.0
# The Outfit                                  0.0                  0.0
# Turning Red                                 0.0                  0.0
# Sonic the Hedgehog 2                        0.0                  0.0
# Yaksha: Ruthless Operations                 0.0                  0.0
# Moonfall                                    0.0                  0.0
# Uncharted                                   0.0                  0.0
# All the Old Knives                          0.0                  0.0
# Blacklight                                  0.0                  0.0
#
#                              actionmatthewwolf  actionmatthiasschoenaerts  \
# title
# The Batman                                 0.0                        0.0
# Spider-Man: No Way Home                    0.0                        0.0
# The Outfit                                 0.0                        0.0
# Turning Red                                0.0                        0.0
# Sonic the Hedgehog 2                       0.0                        0.0
# Yaksha: Ruthless Operations                0.0                        0.0
# Moonfall                                   0.0                        0.0
# Uncharted                                  0.0                        0.0
# All the Old Knives                         0.0                        0.0
# Blacklight                                 0.0                        0.0
#
#                              actionmattmccolm  actionmattmccoy  ...  \
# title                                                           ...
# The Batman                                0.0              0.0  ...
# Spider-Man: No Way Home                   0.0              0.0  ...
# The Outfit                                0.0              0.0  ...
# Turning Red                               0.0              0.0  ...
# Sonic the Hedgehog 2                      0.0              0.0  ...
# Yaksha: Ruthless Operations               0.0              0.0  ...
# Moonfall                                  0.0              0.0  ...
# Uncharted                                 0.0              0.0  ...
# All the Old Knives                        0.0              0.0  ...
# Blacklight                                0.0              0.0  ...
#
#                              actionmichaelbeck  actionmichaelbell  \
# title
# The Batman                                 0.0                0.0
# Spider-Man: No Way Home                    0.0                0.0
# The Outfit                                 0.0                0.0
# Turning Red                                0.0                0.0
# Sonic the Hedgehog 2                       0.0                0.0
# Yaksha: Ruthless Operations                0.0                0.0
# Moonfall                                   0.0                0.0
# Uncharted                                  0.0                0.0
# All the Old Knives                         0.0                0.0
# Blacklight                                 0.0                0.0
#
#                              actionmichaelbiehn  actionmichaelbloom  \
# title
# The Batman                                  0.0                 0.0
# Spider-Man: No Way Home                     0.0                 0.0
# The Outfit                                  0.0                 0.0
# Turning Red                                 0.0                 0.0
# Sonic the Hedgehog 2                        0.0                 0.0
# Yaksha: Ruthless Operations                 0.0                 0.0
# Moonfall                                    0.0                 0.0
# Uncharted                                   0.0                 0.0
# All the Old Knives                          0.0                 0.0
# Blacklight                                  0.0                 0.0
#
#                              actionmichaelbowen  actionmichaelbrandon  \
# title
# The Batman                                  0.0                   0.0
# Spider-Man: No Way Home                     0.0                   0.0
# The Outfit                                  0.0                   0.0
# Turning Red                                 0.0                   0.0
# Sonic the Hedgehog 2                        0.0                   0.0
# Yaksha: Ruthless Operations                 0.0                   0.0
# Moonfall                                    0.0                   0.0
# Uncharted                                   0.0                   0.0
# All the Old Knives                          0.0                   0.0
# Blacklight                                  0.0                   0.0
#
#                              actionmichaelbrianrawlins  actionmichaelbugard  \
# title
# The Batman                                         0.0                  0.0
# Spider-Man: No Way Home                            0.0                  0.0
# The Outfit                                         0.0                  0.0
# Turning Red                                        0.0                  0.0
# Sonic the Hedgehog 2                               0.0                  0.0
# Yaksha: Ruthless Operations                        0.0                  0.0
# Moonfall                                           0.0                  0.0
# Uncharted                                          0.0                  0.0
# All the Old Knives                                 0.0                  0.0
# Blacklight                                         0.0                  0.0
#
#                              actionmichaelcaine  actionmichaelcera
# title
# The Batman                                  0.0                0.0
# Spider-Man: No Way Home                     0.0                0.0
# The Outfit                                  0.0                0.0
# Turning Red                                 0.0                0.0
# Sonic the Hedgehog 2                        0.0                0.0
# Yaksha: Ruthless Operations                 0.0                0.0
# Moonfall                                    0.0                0.0
# Uncharted                                   0.0                0.0
# All the Old Knives                          0.0                0.0
# Blacklight                                  0.0                0.0
#
# [10 rows x 70 columns]
# (230160, 460309)

# %% [markdown]
# <h3>Recommender Function<h3>

# %%
from sklearn.metrics.pairwise import cosine_similarity
import skimage.io as io

# Function that takes in movie title as input and outputs most similar movies
def get_recommendations(title):
    # Get the index of the movie that matches the title
    idx = df.index[df['title'] == title][0]
    print(idx)
    # show given movie poster
    # try:
    #     a = io.imread(f'https://image.tmdb.org/t/p/w500/{df.loc[idx, "poster_path"]}')
    #     plt.imshow(a)
    #     plt.axis('off')
    #     plt.title(title)
    #     plt.show()
    # except:pass
    
    # print('Recommendations\n')


    # Get the pairwsie similarity scores of all movies with that movie
    sim_scores = list(enumerate(
        cosine_similarity(
            tfidf_matrix,
            tfidf_matrix[idx])))
    
  

    # # Sort the movies based on the similarity scores
    # sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)

    # # Get the scores of the 10 most similar movies
    # sim_scores = sim_scores[1:10]

    # # Get the movie indices
    # movie_indices = [i[0] for i in sim_scores]

    # # Return the top 10 most similar movies
    # result = df.iloc[movie_indices]
    
    # # show reco. movie posters
    # fig, ax = plt.subplots(3, 3, figsize=(15,20))
    # ax=ax.flatten()
    # for i, j in enumerate(result.poster_path):
    #     try:
    #         ax[i].axis('off')
    #         ax[i].set_title(result.iloc[i].title,fontsize=22)
    #         a = io.imread(f'https://image.tmdb.org/t/p/w500/{j}')
    #         ax[i].imshow(a)          
    #     except: pass
    # fig.tight_layout()
    # fig.show()

# %%
get_recommendations("Godzilla")
# Out:
# 745
